# %% [markdown]
# # TFMA Visualization

# %%
# To enable TFMA visulization, please enable the Notebook Extention and restart kernel.
# !jupyter nbextension enable --py widgetsnbextension
# !jupyter nbextension enable --py tensorflow_model_analysis
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
# 2020-05-15 18:18:12.478192: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory
# 2020-05-15 18:18:12.478273: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory
# 2020-05-15 18:18:12.478283: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Enabling notebook extension tensorflow_model_analysis/extension...
#       - Validating: OK

# %%
import tensorflow_model_analysis as tfma
import tensorflow as tf
import os
import json

eval_result_folder = "/var/tmp/santander/keras-tft/Evaluator/evaluation/8"
# replace your evaluation result path which should contains a "eval_config.json"
eval_result = tfma.load_eval_result(eval_result_folder)
print('eval result loaded')
# Out:
# WARNING:tensorflow:From /usr/local/google/home/renming/envtfx/lib/python3.7/site-packages/tensorflow_model_analysis/writers/metrics_and_plots_serialization.py:127: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# eval result loaded

# %%
def get_slicing_spec(eval_result_folder):
    config_file=tf.io.gfile.GFile(os.path.join(eval_result_folder, 'eval_config.json'), 'r')
    config=json.loads(config_file.read())
    feature_keys=list(filter(lambda x: 'featureKeys' in x, config['evalConfig']['slicingSpecs']))
    columns=[] if len(feature_keys) == 0 else feature_keys[0]['featureKeys']
    return tfma.slicer.SingleSliceSpec(columns=columns)

# Or hardcode one
# tfma.view.render_slicing_metrics(eval_result, slicing_column='var_0')
slicing_spec = get_slicing_spec(eval_result_folder)
tfma.view.render_slicing_metrics(eval_result, slicing_spec=slicing_spec)
print('hello')
# Out:
# hello

# %% [markdown]
# # TensorBoard Visualization on TFT

# %% [markdown]
# ```shell
# curl https://raw.githubusercontent.com/tensorflow/tensorflow/master/tensorflow/python/tools/import_pb_to_tensorboard.py > import_pb_to_tensorboard.py
#
# python import_pb_to_tensorboard.py --model_dir /var/tmp/santander/pusher/1587532679/ --log_dir /var/tmp/santander/tmp/
#
# tensorboard --logdir=/var/tmp/santander/tmp/
# ```

# %% [markdown]
# # Beam

# %%
import apache_beam as beam

data = []
with beam.Pipeline() as pipeline:
  intrim = pipeline | 'Data' >> beam.Create([
          ('p', 1),
          ('a', 2),
          ('z', 3),
          ('m', 2),])
  intrim = intrim | 'Sink' >> beam.Map(lambda item: data.append(item))

print(data)
data.sort(key = lambda item: item[0] )
print(data)

with open('/var/tmp/tmp.csv', 'w') as file:
  file.write('ID_code,target\n')
  for item in data:
    file.write('{0},{1}\n'.format(item[0], item[1])) 
    
# !cat /var/tmp/tmp.csv
# Out:
# [('p', 1), ('a', 2), ('z', 3), ('m', 2)]
# [('a', 2), ('m', 2), ('p', 1), ('z', 3)]
# ID_code,target
# a,2
# m,2
# p,1
# z,3

# %%
import apache_beam as beam
from apache_beam.transforms.userstate import CombiningValueStateSpec
from apache_beam.transforms.core import GroupByKey

class IndexAssigningStatefulDoFn(beam.DoFn):
  # per-key-and-window, first in element is key
  index_state = beam.DoFn.StateParam(CombiningValueStateSpec('index', sum))
  
  def __init__(self):
    # unmanaged state only can work in single-processor multi-thread env
    self.unmanaged_state = 10
  
  def process(self, element, index=index_state):
    current_index = index.read()
    index.add(1)
    self.unmanaged_state = self.unmanaged_state + 1
    print(self.unmanaged_state)
    yield (element, current_index)

def sort_data(data):
  result = data.copy()
  result.sort(key=lambda item: item[0])
  return result

with beam.Pipeline(options=beam.options.pipeline_options.PipelineOptions(direct_num_workers=4)) as pipeline:
  intrim = pipeline | 'Data' >> beam.Create([
          ('p', 1),
          ('a', 2),
          ('p', 3),
          ('m', 2),])
  intrim = intrim | beam.Map(lambda it: (0, it)) # same key
  intrim = intrim | 'window' >> beam.WindowInto(beam.window.GlobalWindows()) # same window
  intrim = intrim | GroupByKey() # all to one
  # intrim = intrim | beam.ParDo(IndexAssigningStatefulDoFn())
  intrim = intrim | beam.Map(lambda item: item[1]) # remove dummy key
  intrim = intrim | beam.Map(sort_data) # sort all-in-one
  intrim = intrim | beam.Map(print)
# Out:
# [('a', 2), ('m', 2), ('p', 1), ('p', 3)]

# %% [markdown]
# # ad-hoc

# %%
import tensorflow as tf

model = tf.keras.models.load_model('/var/tmp/santander/keras-tft/Trainer/model/7/serving_model_dir/')

# %%
import apache_beam as beam

with beam.Pipeline() as pipeline:
  test_data = pipeline | beam.io.ReadFromTFRecord(file_pattern=io_utils.all_files_pattern(transformed_examples_uri))
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# var_0_tft (InputLayer)       [(None, 1)]               0
# _________________________________________________________________
# var_1_tft (InputLayer)       [(None, 1)]               0
# _________________________________________________________________
# var_2_tft (InputLayer)       [(None, 1)]               0
# _________________________________________________________________
# var_3_tft (InputLayer)       [(None, 1)]               0
# _________________________________________________________________
# var_4_tft (InputLayer)       [(None, 1)]               0
# _________________________________________________________________
# var_5_tft (InputLayer)       [(None, 1)]               0
# _________________________________________________________________
# var_6_tft (InputLayer)       [(None, 1)]               0
# _________________________________________________________________
# var_7_tft (InputLayer)       [(None, 1)]               0
# _________________________________________________________________
# var_8_tft (InputLayer)       [(None, 1)]               0
# _________________________________________________________________
# var_9_tft (InputLayer)       [(None, 1)]               0
# _________________________________________________________________
# var_10_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_11_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_12_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_13_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_14_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_15_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_16_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_17_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_18_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_19_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_20_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_21_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_22_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_23_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_24_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_25_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_26_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_27_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_28_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_29_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_30_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_31_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_32_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_33_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_34_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_35_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_36_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_37_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_38_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_39_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_40_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_41_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_42_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_43_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_44_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_45_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_46_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_47_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_48_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_49_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_50_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_51_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_52_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_53_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_54_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_55_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_56_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_57_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_58_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_59_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_60_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_61_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_62_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_63_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_64_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_65_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_66_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_67_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_68_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_69_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_70_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_71_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_72_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_73_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_74_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_75_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_76_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_77_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_78_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_79_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_80_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_81_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_82_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_83_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_84_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_85_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_86_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_87_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_88_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_89_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_90_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_91_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_92_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_93_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_94_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_95_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_96_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_97_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_98_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_99_tft (InputLayer)      [(None, 1)]               0
# _________________________________________________________________
# var_100_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_101_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_102_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_103_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_104_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_105_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_106_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_107_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_108_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_109_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_110_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_111_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_112_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_113_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_114_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_115_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_116_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_117_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_118_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_119_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_120_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_121_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_122_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_123_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_124_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_125_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_126_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_127_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_128_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_129_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_130_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_131_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_132_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_133_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_134_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_135_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_136_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_137_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_138_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_139_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_140_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_141_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_142_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_143_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_144_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_145_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_146_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_147_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_148_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_149_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_150_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_151_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_152_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_153_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_154_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_155_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_156_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_157_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_158_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_159_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_160_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_161_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_162_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_163_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_164_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_165_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_166_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_167_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_168_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_169_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_170_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_171_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_172_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_173_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_174_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_175_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_176_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_177_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_178_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_179_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_180_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_181_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_182_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_183_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_184_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_185_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_186_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_187_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_188_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_189_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_190_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_191_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_192_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_193_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_194_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_195_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_196_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_197_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_198_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# var_199_tft (InputLayer)     [(None, 1)]               0
# _________________________________________________________________
# concatenate (Concatenate)    multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  19296
# _________________________________________________________________
# dense_1 (Dense)              multiple                  2328
# _________________________________________________________________
# dense_2 (Dense)              multiple                  25
# _________________________________________________________________
# transform_features_layer (Tr multiple                  0
# =================================================================
# Total params: 21,649
# Trainable params: 21,649
# Non-trainable params: 0
# _________________________________________________________________
